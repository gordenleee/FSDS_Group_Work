# %%
pip install linearmodels
# Out:
# Requirement already satisfied: linearmodels in /opt/conda/lib/python3.11/site-packages (5.3)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (1.24.4)
# Requirement already satisfied: pandas>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (2.1.0)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (1.11.2)
# Requirement already satisfied: statsmodels>=0.12.0 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.4 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (1.0.0)
# Requirement already satisfied: Cython>=0.29.34 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (0.29.36)
# Requirement already satisfied: pyhdfe>=0.1 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (0.2.0)
# Requirement already satisfied: formulaic>=0.6.5 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (0.6.6)
# Requirement already satisfied: setuptools-scm[toml]<8.0.0,>=7.0.0 in /opt/conda/lib/python3.11/site-packages (from linearmodels) (7.1.0)
# Requirement already satisfied: astor>=0.8 in /opt/conda/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (4.7.1)
# Requirement already satisfied: wrapt>=1.0 in /opt/conda/lib/python3.11/site-packages (from formulaic>=0.6.5->linearmodels) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.0->linearmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.0->linearmodels) (2023.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from setuptools-scm[toml]<8.0.0,>=7.0.0->linearmodels) (23.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from setuptools-scm[toml]<8.0.0,>=7.0.0->linearmodels) (68.1.2)
# Requirement already satisfied: patsy>=0.5.2 in /opt/conda/lib/python3.11/site-packages (from statsmodels>=0.12.0->linearmodels) (0.5.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.12.0->linearmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
from linearmodels import RandomEffects
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("all_data126.csv", encoding="ISO-8859-1",parse_dates=['last_review'])

# %%
df.head()
# Out:
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 1   70374572  23013522                               3
# 2   25587547  25796711                               1
# 3   57607790  29060134                               1
# 4  228095684  30374086                               3
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 1    Spacious room with double bed for 2, Twickenham               1
# 2  Stunning Central London Apartment Close The River               7
# 3     Recently renovated fabulous four bedroom house              14
# 4    Lovely cosy flat for 4 in Heart of North London               3
#
#    latitude        room_type  price  availability_365  number_of_reviews  \
# 0  51.44473     Private room   35.0               278                 47
# 1  51.45867     Private room   19.0                23                131
# 2  51.47398  Entire home/apt  103.0               317                  8
# 3  51.52716  Entire home/apt   85.0               346                  5
# 4  51.59118  Entire home/apt   85.0               139                 16
#
#    longitude last_review           neighbourhood  reviews_per_month  year
# 0   -0.37900  2019-11-06    Richmond upon Thames               2.27  2019
# 1   -0.34444  2019-11-06                Hounslow               6.52  2019
# 2   -0.21531  2019-11-06  Hammersmith and Fulham               0.51  2019
# 3   -0.44164  2019-11-06              Hillingdon               0.40  2019
# 4   -0.16670  2019-11-06                  Barnet               1.52  2019

# %%
df.dtypes
# Out:
# host_id                                    int64
# id                                         int64
# calculated_host_listings_count             int64
# name                                      object
# minimum_nights                             int64
# latitude                                 float64
# room_type                                 object
# price                                    float64
# availability_365                           int64
# number_of_reviews                          int64
# longitude                                float64
# last_review                       datetime64[ns]
# neighbourhood                             object
# reviews_per_month                        float64
# year                                       int64
# dtype: object

# %%
df_filtered = df[df["reviews_per_month"] > 0.5]
#define active offers as those listings which could be booked at least for one night in the following 60 days at the moment of scraping.
#Use the number of reviews to estimate the number of bookings, thereby selecting properties with more than 0.5 reviews per month as effective listings
#The analysis was restricted to active listings throughout the analysis.

# %%
top_2_percent = df_filtered["price"].quantile(0.98)
bottom_2_percent = df_filtered["price"].quantile(0.02)
#the average price was calculated for each city and month, based on the nightly price of available listings. 
#To eliminate outlier observations, the top 2% and bottom 2% percentile of offers were not taken into consideration.

# %%
df_filtered1 = df_filtered[
    (df_filtered["price"] >= bottom_2_percent) & (df_filtered["price"] <= top_2_percent)
]

# %%
df_filtered1.head()
# Out:
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 2   25587547  25796711                               1
# 4  228095684  30374086                               3
# 5  234271729  31300930                               1
# 6  246523174  34733139                               2
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 2  Stunning Central London Apartment Close The River               7
# 4    Lovely cosy flat for 4 in Heart of North London               3
# 5      ALPINE GUEST HOUSE. Detached & self-contained               1
# 6                                room in the cottage               2
#
#    latitude        room_type  price  availability_365  number_of_reviews  \
# 0  51.44473     Private room   35.0               278                 47
# 2  51.47398  Entire home/apt  103.0               317                  8
# 4  51.59118  Entire home/apt   85.0               139                 16
# 5  51.37960     Private room   32.0               140                 50
# 6  51.59863     Private room   30.0               157                 15
#
#    longitude last_review           neighbourhood  reviews_per_month  year
# 0   -0.37900  2019-11-06    Richmond upon Thames               2.27  2019
# 2   -0.21531  2019-11-06  Hammersmith and Fulham               0.51  2019
# 4   -0.16670  2019-11-06                  Barnet               1.52  2019
# 5   -0.27561  2019-11-06    Kingston upon Thames               5.17  2019
# 6   -0.39746  2019-11-06                  Harrow               2.69  2019

# %%
df_filtered2 = df_filtered1[df_filtered1["availability_365"] > 0]

# %%
df_filtered2.head()
# Out:
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 2   25587547  25796711                               1
# 4  228095684  30374086                               3
# 5  234271729  31300930                               1
# 6  246523174  34733139                               2
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 2  Stunning Central London Apartment Close The River               7
# 4    Lovely cosy flat for 4 in Heart of North London               3
# 5      ALPINE GUEST HOUSE. Detached & self-contained               1
# 6                                room in the cottage               2
#
#    latitude        room_type  price  availability_365  number_of_reviews  \
# 0  51.44473     Private room   35.0               278                 47
# 2  51.47398  Entire home/apt  103.0               317                  8
# 4  51.59118  Entire home/apt   85.0               139                 16
# 5  51.37960     Private room   32.0               140                 50
# 6  51.59863     Private room   30.0               157                 15
#
#    longitude last_review           neighbourhood  reviews_per_month  year
# 0   -0.37900  2019-11-06    Richmond upon Thames               2.27  2019
# 2   -0.21531  2019-11-06  Hammersmith and Fulham               0.51  2019
# 4   -0.16670  2019-11-06                  Barnet               1.52  2019
# 5   -0.27561  2019-11-06    Kingston upon Thames               5.17  2019
# 6   -0.39746  2019-11-06                  Harrow               2.69  2019

# %%
df_filtered2.dtypes
# Out:
# host_id                                    int64
# id                                         int64
# calculated_host_listings_count             int64
# name                                      object
# minimum_nights                             int64
# latitude                                 float64
# room_type                                 object
# price                                    float64
# availability_365                           int64
# number_of_reviews                          int64
# longitude                                float64
# last_review                       datetime64[ns]
# neighbourhood                             object
# reviews_per_month                        float64
# year                                       int64
# dtype: object

# %%
df_filtered3 = df_filtered2[
    (df_filtered2["last_review"].dt.year >= 2019)
    & (df_filtered2["last_review"].dt.year <= 2023)
]
#Properties that received reviews between 2019 and 2023 are determined to be effective listings.

# %%
columns_to_normalize = ["availability_365", "number_of_reviews", "reviews_per_month"]

# %%
scaler = MinMaxScaler()# Creating a Normaliser Instance

# %%
# Normalise selected columns and create new columns

df_filtered3["availability_365" + "_normalized"] = scaler.fit_transform(
    df_filtered3[["availability_365"]]
)

# Show first few rows of data to validate results
df_filtered3.head()
# Out:
# /tmp/ipykernel_5793/3870308804.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["availability_365" + "_normalized"] = scaler.fit_transform(
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 2   25587547  25796711                               1
# 4  228095684  30374086                               3
# 5  234271729  31300930                               1
# 6  246523174  34733139                               2
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 2  Stunning Central London Apartment Close The River               7
# 4    Lovely cosy flat for 4 in Heart of North London               3
# 5      ALPINE GUEST HOUSE. Detached & self-contained               1
# 6                                room in the cottage               2
#
#    latitude        room_type  price  availability_365  number_of_reviews  \
# 0  51.44473     Private room   35.0               278                 47
# 2  51.47398  Entire home/apt  103.0               317                  8
# 4  51.59118  Entire home/apt   85.0               139                 16
# 5  51.37960     Private room   32.0               140                 50
# 6  51.59863     Private room   30.0               157                 15
#
#    longitude last_review           neighbourhood  reviews_per_month  year  \
# 0   -0.37900  2019-11-06    Richmond upon Thames               2.27  2019
# 2   -0.21531  2019-11-06  Hammersmith and Fulham               0.51  2019
# 4   -0.16670  2019-11-06                  Barnet               1.52  2019
# 5   -0.27561  2019-11-06    Kingston upon Thames               5.17  2019
# 6   -0.39746  2019-11-06                  Harrow               2.69  2019
#
#    availability_365_normalized
# 0                     0.760989
# 2                     0.868132
# 4                     0.379121
# 5                     0.381868
# 6                     0.428571

# %%
df_filtered3["number_of_reviews" + "_normalized"] = scaler.fit_transform(
    df_filtered3[["number_of_reviews"]]
)
df_filtered3["reviews_per_month" + "_normalized"] = scaler.fit_transform(
    df_filtered3[["reviews_per_month"]]
)
# Out:
# /tmp/ipykernel_5793/1637088241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["number_of_reviews" + "_normalized"] = scaler.fit_transform(
# /tmp/ipykernel_5793/1637088241.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["reviews_per_month" + "_normalized"] = scaler.fit_transform(

# %%
df_filtered3["market_activity"] = (
    df_filtered3["availability_365_normalized"]
    + df_filtered3["number_of_reviews_normalized"]
    + df_filtered3["reviews_per_month_normalized"]
)
# Out:
# /tmp/ipykernel_5793/2071844040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["market_activity"] = (

# %%
df_filtered3.head()
# Out:
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 2   25587547  25796711                               1
# 4  228095684  30374086                               3
# 5  234271729  31300930                               1
# 6  246523174  34733139                               2
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 2  Stunning Central London Apartment Close The River               7
# 4    Lovely cosy flat for 4 in Heart of North London               3
# 5      ALPINE GUEST HOUSE. Detached & self-contained               1
# 6                                room in the cottage               2
#
#    latitude        room_type  price  availability_365  number_of_reviews  \
# 0  51.44473     Private room   35.0               278                 47
# 2  51.47398  Entire home/apt  103.0               317                  8
# 4  51.59118  Entire home/apt   85.0               139                 16
# 5  51.37960     Private room   32.0               140                 50
# 6  51.59863     Private room   30.0               157                 15
#
#    longitude last_review           neighbourhood  reviews_per_month  year  \
# 0   -0.37900  2019-11-06    Richmond upon Thames               2.27  2019
# 2   -0.21531  2019-11-06  Hammersmith and Fulham               0.51  2019
# 4   -0.16670  2019-11-06                  Barnet               1.52  2019
# 5   -0.27561  2019-11-06    Kingston upon Thames               5.17  2019
# 6   -0.39746  2019-11-06                  Harrow               2.69  2019
#
#    availability_365_normalized  number_of_reviews_normalized  \
# 0                     0.760989                      0.030599
# 2                     0.868132                      0.005208
# 4                     0.379121                      0.010417
# 5                     0.381868                      0.032552
# 6                     0.428571                      0.009766
#
#    reviews_per_month_normalized  market_activity
# 0                      0.014943         0.806531
# 2                      0.000000         0.873340
# 4                      0.008575         0.398113
# 5                      0.039565         0.453986
# 6                      0.018509         0.456846

# %%
df_filtered3["year_copy"] = df_filtered3["year"]
# Out:
# /tmp/ipykernel_5793/3524362711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["year_copy"] = df_filtered3["year"]

# %%
# Assumes COVID period of 2020 and 2021
df_filtered3["covid_period"] = df_filtered3["year"].isin([2020, 2021]).astype(int)
# Out:
# /tmp/ipykernel_5793/3104444095.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["covid_period"] = df_filtered3["year"].isin([2020, 2021]).astype(int)

# %%
df_filtered3.head()
# Out:
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 2   25587547  25796711                               1
# 4  228095684  30374086                               3
# 5  234271729  31300930                               1
# 6  246523174  34733139                               2
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 2  Stunning Central London Apartment Close The River               7
# 4    Lovely cosy flat for 4 in Heart of North London               3
# 5      ALPINE GUEST HOUSE. Detached & self-contained               1
# 6                                room in the cottage               2
#
#    latitude        room_type  price  availability_365  number_of_reviews  ...  \
# 0  51.44473     Private room   35.0               278                 47  ...
# 2  51.47398  Entire home/apt  103.0               317                  8  ...
# 4  51.59118  Entire home/apt   85.0               139                 16  ...
# 5  51.37960     Private room   32.0               140                 50  ...
# 6  51.59863     Private room   30.0               157                 15  ...
#
#    last_review           neighbourhood reviews_per_month  year  \
# 0   2019-11-06    Richmond upon Thames              2.27  2019
# 2   2019-11-06  Hammersmith and Fulham              0.51  2019
# 4   2019-11-06                  Barnet              1.52  2019
# 5   2019-11-06    Kingston upon Thames              5.17  2019
# 6   2019-11-06                  Harrow              2.69  2019
#
#    availability_365_normalized  number_of_reviews_normalized  \
# 0                     0.760989                      0.030599
# 2                     0.868132                      0.005208
# 4                     0.379121                      0.010417
# 5                     0.381868                      0.032552
# 6                     0.428571                      0.009766
#
#    reviews_per_month_normalized  market_activity  year_copy  covid_period
# 0                      0.014943         0.806531       2019             0
# 2                      0.000000         0.873340       2019             0
# 4                      0.008575         0.398113       2019             0
# 5                      0.039565         0.453986       2019             0
# 6                      0.018509         0.456846       2019             0
#
# [5 rows x 21 columns]

# %%
df_filtered3["year_2019"] = (df_filtered3["year"] == 2019).astype(int)
# Out:
# /tmp/ipykernel_5793/2137878903.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["year_2019"] = (df_filtered3["year"] == 2019).astype(int)

# %%
df_filtered3["year_2023"] = (df_filtered3["year"] == 2023).astype(int)
# Out:
# /tmp/ipykernel_5793/3157473834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered3["year_2023"] = (df_filtered3["year"] == 2023).astype(int)

# %%
df_filtered3.head()
# Out:
#      host_id        id  calculated_host_listings_count  \
# 0   49602995   9582415                               1
# 2   25587547  25796711                               1
# 4  228095684  30374086                               3
# 5  234271729  31300930                               1
# 6  246523174  34733139                               2
#
#                                                 name  minimum_nights  \
# 0  Single/Twin/Double Ensuite near Twickenham Sta...               1
# 2  Stunning Central London Apartment Close The River               7
# 4    Lovely cosy flat for 4 in Heart of North London               3
# 5      ALPINE GUEST HOUSE. Detached & self-contained               1
# 6                                room in the cottage               2
#
#    latitude        room_type  price  availability_365  number_of_reviews  ...  \
# 0  51.44473     Private room   35.0               278                 47  ...
# 2  51.47398  Entire home/apt  103.0               317                  8  ...
# 4  51.59118  Entire home/apt   85.0               139                 16  ...
# 5  51.37960     Private room   32.0               140                 50  ...
# 6  51.59863     Private room   30.0               157                 15  ...
#
#    reviews_per_month  year availability_365_normalized  \
# 0               2.27  2019                    0.760989
# 2               0.51  2019                    0.868132
# 4               1.52  2019                    0.379121
# 5               5.17  2019                    0.381868
# 6               2.69  2019                    0.428571
#
#    number_of_reviews_normalized  reviews_per_month_normalized  \
# 0                      0.030599                      0.014943
# 2                      0.005208                      0.000000
# 4                      0.010417                      0.008575
# 5                      0.032552                      0.039565
# 6                      0.009766                      0.018509
#
#    market_activity  year_copy  covid_period  year_2019  year_2023
# 0         0.806531       2019             0          1          0
# 2         0.873340       2019             0          1          0
# 4         0.398113       2019             0          1          0
# 5         0.453986       2019             0          1          0
# 6         0.456846       2019             0          1          0
#
# [5 rows x 23 columns]

# %%
df_filtered3 = pd.get_dummies(df_filtered3, columns=["room_type"], drop_first=True)

# %%
df_filtered3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149746 entries, 0 to 369768
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   host_id                         149746 non-null  int64
#  1   id                              149746 non-null  int64
#  2   calculated_host_listings_count  149746 non-null  int64
#  3   name                            149746 non-null  object
#  4   minimum_nights                  149746 non-null  int64
#  5   latitude                        149746 non-null  float64
#  6   price                           149746 non-null  float64
#  7   availability_365                149746 non-null  int64
#  8   number_of_reviews               149746 non-null  int64
#  9   longitude                       149746 non-null  float64
#  10  last_review                     149746 non-null  datetime64[ns]
#  11  neighbourhood                   149746 non-null  object
#  12  reviews_per_month               149746 non-null  float64
#  13  year                            149746 non-null  int64
#  14  availability_365_normalized     149746 non-null  float64
#  15  number_of_reviews_normalized    149746 non-null  float64
#  16  reviews_per_month_normalized    149746 non-null  float64
#  17  market_activity                 149746 non-null  float64
#  18  year_copy                       149746 non-null  int64
#  19  covid_period                    149746 non-null  int64
#  20  year_2019                       149746 non-null  int64
#  21  year_2023                       149746 non-null  int64
#  22  room_type_Hotel room            149746 non-null  bool
#  23  room_type_Private room          149746 non-null  bool
#  24  room_type_Shared room           149746 non-null  bool
# dtypes: bool(3), datetime64[ns](1), float64(8), int64(11), object(2)
# memory usage: 26.7+ MB

# %%
start_date = pd.to_datetime('2020-03-17')
end_date = pd.to_datetime('2021-12-13')

# Create dummy variable rev_covid
df_filtered3['rev_covid'] = ((df_filtered3['last_review'] >= start_date) & (df_filtered3['last_review'] <= end_date)).astype(int)

# %%
df_filtered3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149746 entries, 0 to 369768
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   host_id                         149746 non-null  int64
#  1   id                              149746 non-null  int64
#  2   calculated_host_listings_count  149746 non-null  int64
#  3   name                            149746 non-null  object
#  4   minimum_nights                  149746 non-null  int64
#  5   latitude                        149746 non-null  float64
#  6   price                           149746 non-null  float64
#  7   availability_365                149746 non-null  int64
#  8   number_of_reviews               149746 non-null  int64
#  9   longitude                       149746 non-null  float64
#  10  last_review                     149746 non-null  datetime64[ns]
#  11  neighbourhood                   149746 non-null  object
#  12  reviews_per_month               149746 non-null  float64
#  13  year                            149746 non-null  int64
#  14  availability_365_normalized     149746 non-null  float64
#  15  number_of_reviews_normalized    149746 non-null  float64
#  16  reviews_per_month_normalized    149746 non-null  float64
#  17  market_activity                 149746 non-null  float64
#  18  year_copy                       149746 non-null  int64
#  19  covid_period                    149746 non-null  int64
#  20  year_2019                       149746 non-null  int64
#  21  year_2023                       149746 non-null  int64
#  22  room_type_Hotel room            149746 non-null  bool
#  23  room_type_Private room          149746 non-null  bool
#  24  room_type_Shared room           149746 non-null  bool
#  25  rev_covid                       149746 non-null  int64
# dtypes: bool(3), datetime64[ns](1), float64(8), int64(12), object(2)
# memory usage: 27.8+ MB

# %%
df_filtered3 = df_filtered3.set_index(["id", "year_copy"])

# %%
df_filtered3.head()
# Out:
#                       host_id  calculated_host_listings_count  \
# id       year_copy
# 9582415  2019        49602995                               1
# 25796711 2019        25587547                               1
# 30374086 2019       228095684                               3
# 31300930 2019       234271729                               1
# 34733139 2019       246523174                               2
#
#                                                                  name  \
# id       year_copy
# 9582415  2019       Single/Twin/Double Ensuite near Twickenham Sta...
# 25796711 2019       Stunning Central London Apartment Close The River
# 30374086 2019         Lovely cosy flat for 4 in Heart of North London
# 31300930 2019           ALPINE GUEST HOUSE. Detached & self-contained
# 34733139 2019                                     room in the cottage
#
#                     minimum_nights  latitude  price  availability_365  \
# id       year_copy
# 9582415  2019                    1  51.44473   35.0               278
# 25796711 2019                    7  51.47398  103.0               317
# 30374086 2019                    3  51.59118   85.0               139
# 31300930 2019                    1  51.37960   32.0               140
# 34733139 2019                    2  51.59863   30.0               157
#
#                     number_of_reviews  longitude last_review  ...  \
# id       year_copy                                            ...
# 9582415  2019                      47   -0.37900  2019-11-06  ...
# 25796711 2019                       8   -0.21531  2019-11-06  ...
# 30374086 2019                      16   -0.16670  2019-11-06  ...
# 31300930 2019                      50   -0.27561  2019-11-06  ...
# 34733139 2019                      15   -0.39746  2019-11-06  ...
#
#                    number_of_reviews_normalized  reviews_per_month_normalized  \
# id       year_copy
# 9582415  2019                          0.030599                      0.014943
# 25796711 2019                          0.005208                      0.000000
# 30374086 2019                          0.010417                      0.008575
# 31300930 2019                          0.032552                      0.039565
# 34733139 2019                          0.009766                      0.018509
#
#                     market_activity  covid_period  year_2019  year_2023  \
# id       year_copy
# 9582415  2019              0.806531             0          1          0
# 25796711 2019              0.873340             0          1          0
# 30374086 2019              0.398113             0          1          0
# 31300930 2019              0.453986             0          1          0
# 34733139 2019              0.456846             0          1          0
#
#                     room_type_Hotel room  room_type_Private room  \
# id       year_copy
# 9582415  2019                      False                    True
# 25796711 2019                      False                   False
# 30374086 2019                      False                   False
# 31300930 2019                      False                    True
# 34733139 2019                      False                    True
#
#                     room_type_Shared room  rev_covid
# id       year_copy
# 9582415  2019                       False          0
# 25796711 2019                       False          0
# 30374086 2019                       False          0
# 31300930 2019                       False          0
# 34733139 2019                       False          0
#
# [5 rows x 24 columns]

# %%
df_filtered3["log_price"] = np.log(df_filtered3["price"])

# %%
# Selection of independent and dependent variables

independent_vars = [
    "market_activity",
    "covid_period",
    "year_2019",
    "year_2023",
    "room_type_Shared room",
    "room_type_Private room",'rev_covid'
]
dependent_var = "log_price"  # previously calculated composite indices

# Prepare the dependent and independent variables for the model
y = df_filtered3[dependent_var]
X = df_filtered3[independent_vars]

# Add constant term
X = sm.add_constant(X)

# Random effects modelling
model = RandomEffects(y, X)
results = model.fit()

# Output model results
print(results)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:              log_price   R-squared:                        0.7910
# Estimator:              RandomEffects   R-squared (Between):              0.4742
# No. Observations:              149746   R-squared (Within):               0.2129
# Date:                Sat, Dec 16 2023   R-squared (Overall):              0.4678
# Time:                        21:49:57   Log-likelihood                    8848.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   8.094e+04
# Entities:                      100468   P-value                           0.0000
# Avg Obs:                       1.4905   Distribution:                F(7,149738)
# Min Obs:                       1.0000
# Max Obs:                       5.0000   F-statistic (robust):          1.462e+04
#                                         P-value                           0.0000
# Time periods:                       5   Distribution:                F(7,149738)
# Avg Obs:                    2.995e+04
# Min Obs:                    2.299e+04
# Max Obs:                    4.153e+04
#
#                                    Parameter Estimates
# ==========================================================================================
#                         Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------
# const                      5.0750     0.0032     1564.0     0.0000      5.0686      5.0813
# market_activity            0.1163     0.0037     31.836     0.0000      0.1091      0.1234
# covid_period              -0.3113     0.0028    -111.00     0.0000     -0.3168     -0.3058
# year_2019                 -0.2771     0.0028    -98.109     0.0000     -0.2826     -0.2716
# year_2023                  0.0182     0.0024     7.6057     0.0000      0.0135      0.0228
# room_type_Shared room     -1.0447     0.0208    -50.319     0.0000     -1.0854     -1.0040
# room_type_Private room    -0.8926     0.0034    -265.37     0.0000     -0.8992     -0.8860
# rev_covid                 -0.0211     0.0027    -7.8946     0.0000     -0.0263     -0.0159
# ==========================================================================================

# %%
# Create the Data_clean folder
data_folder = "Data_clean"
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Export DataFrame to CSV file
output_file = os.path.join(data_folder, "cleaned_data_12061010.csv")
df_filtered3.to_csv(output_file, index=False)
